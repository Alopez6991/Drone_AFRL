# %% [markdown]
# # Model Predictive Control

# %%
import importlib.util
import sys
import numpy as np
import matplotlib.pyplot as plt
# Define the file path
file_path = '/home/austin/Nonlinear_and_Data_Driven_Estimation/Drone/MPC_drone_02.py'

# Define the module name
module_name = 'MPC_drone_02'

# Load the module
spec = importlib.util.spec_from_file_location(module_name, file_path)
MPCD = importlib.util.module_from_spec(spec)
sys.modules[module_name] = MPCD
spec.loader.exec_module(MPCD)
# Out:
# Hello from MPC_drone_02.py

# %%
TIME=20
dt=.1
T_length=int(TIME/dt)
# make vx sin wave
t = np.linspace(0,T_length*dt,T_length)
# set vz to t^2 for half the time then t for the other half startign from when t^2 ends
vz= t**2
vx = np.full (T_length,0)
vy = np.full (T_length,0)
psi= np.full (T_length,0)


mpc=MPCD.MpcDron02(vx=vx,vy=vy,vz=vz,psi=psi,dt=dt, n_horizon=10, r_weight=0.0)
# Out:
# ui: 3.501785258978626

# %%
# X,U=mpc.run_mpc()

# %%
# plt.plot(t,U.T[0])

# %%
plt.plot(t,X[:,0])
# get teh derivative of the position to get the velocity
X_dot=np.diff(X[:,1])/dt
plt.plot(t[1:],X_dot,linestyle='dashed')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/austin/Nonlinear_and_Data_Driven_Estimation/Drone/drone_sim_02.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/home/austin/Nonlinear_and_Data_Driven_Estimation/Drone/drone_sim_02.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> plt.plot(t,X[:,0])
#       <a href='vscode-notebook-cell:/home/austin/Nonlinear_and_Data_Driven_Estimation/Drone/drone_sim_02.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> # get teh derivative of the position to get the velocity
#       <a href='vscode-notebook-cell:/home/austin/Nonlinear_and_Data_Driven_Estimation/Drone/drone_sim_02.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> X_dot=np.diff(X[:,1])/dt
#
# NameError: name 'X' is not defined

# %%
# X[:,0]
# X

# %%
# X[:,0]
# X

# %%
plt.rcParams['axes.formatter.useoffset'] = False
# print(X.T[0])
# print(type(X.T[0]))
# print(t)
plt.plot(t,np.array(X.T[0]),label='vx',color='blue',alpha=0.5)
plt.plot(t,vx,label='vx target',color='red',alpha=0.5,linestyle='dashed')
plt.xlabel('time')
plt.ylabel('Velocity')
plt.legend()

# %%
plt.plot(t,np.array(X.T[1]),label='x',color='blue',alpha=0.5)
plt.xlabel('time')
plt.ylabel('Position')
plt.legend()

# %%
plt.plot(t,np.array(U.T[0]),label='u',color='blue',alpha=0.5)

# %%
X[:,0] = np.round(X[:,0].astype(float),3)
